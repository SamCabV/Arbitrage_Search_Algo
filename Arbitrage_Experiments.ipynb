# %%
import pandas as pd
import networkx as nx
import matplotlib.pyplot as plt
import numpy as np

# Import Data
data = pd.read_csv("arbitrage_data.csv")
fro = data.iloc[:,0].to_list()
matrix = []
index = 1

for i in fro:
  matrix.append(data.iloc[:,index].to_list())
  index+=1
print(matrix)
# Out:
# [[1.0, 0.94117, 0.8193, 1.3695, 0.98281, 149.885, 7.31512, 7.02205, 358.93, 18.1802, 4.19782, 11.02455, 36.381, 18.9447], [1.0623, 1.0, 0.87, 1.4562, 0.94534, 158.69375, 7.7591, 7.46106, 381.64142, 19.30693, 4.45473, 11.61611, 38.62408, 20.07499], [1.2204, 1.15, 1.0, 1.66764, 1.08493, 182.26368, 8.90843, 8.56459, 437.98366, 22.16506, 5.11503, 13.33136, 44.34184, 23.04566], [0.73009, 0.68806, 0.59933, 1.0, 0.65052, 109.24863, 5.34018, 5.13407, 262.55065, 13.28691, 3.06622, 7.99152, 26.58085, 13.81479], [1.11986, 1.05756, 0.92089, 1.53637, 1.0, 167.91257, 8.20719, 7.89042, 403.50737, 20.42031, 4.7124, 12.28197, 40.85143, 21.2316], [0.0066, 0.0063, 0.00548, 0.00915, 0.05595, 1.0, 0.04887, 0.04698, 2.40262, 0.12159, 0.02806, 0.07313, 0.24324, 0.12642], [0.13668, 0.12879, 0.11218, 0.18712, 0.12177, 20.44946, 1.0, 0.96101, 49.14496, 2.48708, 0.57394, 1.49588, 4.97548, 2.58589], [0.14238, 0.13398, 0.11669, 0.19464, 0.12666, 21.2708, 1.03974, 1.0, 51.11884, 2.58697, 0.597, 1.55596, 5.17532, 
# ...

# %%
import pandas as pd
import networkx as nx
import matplotlib.pyplot as plt
import numpy as np

# Import Data
data = pd.read_csv("arbitrage_data.csv")
fro = data.iloc[:,0].to_list()
matrix = []
i_index = 0
j_index = 0

# Create a new graph
G = nx.Graph()

for i in fro:
    G.add_node(i)
    matrix.append(data.iloc[:,i_index].to_list())
    i_index+=1
    for j in fro:
      G.add_edge(i, j, weight=matrix[i_index-1][j_index-1])
    j_index+=1

# G.add_edge('USD', 'GBP', weight = 1.0623)

plt.figure(figsize=(12, 8))
# pos = nx.spring_layout(G)
nx.draw_networkx_nodes(G, pos, node_size=1000)
nx.draw_networkx_edges(G, pos)
nx.draw_networkx_labels(G, pos)
# nx.draw_networkx_edge_labels(G, pos, edge_labels={(u, v): {d[matrix[i_index-1][j_index-1]]} for u, v, d in G.edges(data=True)})
plt.title("Exchange Rates")
plt.show()
